# %%
import numpy as np
import pandas as pd
# 画图工具包
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import warnings
warnings.filterwarnings("ignore")
# 在noteBook中使用的命令，可以将图型嵌入到文档中
# %matplotlib inline

# %%
features = pd.read_csv('temps.csv')

#看看数据长什么样子
features.head()
# Out:
#    year  month  day  week  temp_2  temp_1  average  actual  friend
# 0  2016      1    1   Fri      45      45     45.6      45      29
# 1  2016      1    2   Sat      44      45     45.7      44      61
# 2  2016      1    3   Sun      45      44     45.8      41      56
# 3  2016      1    4   Mon      44      41     45.9      40      53
# 4  2016      1    5  Tues      41      40     46.0      44      41

# %% [markdown]
# 数据表中
# * year,moth,day,week分别表示的具体的时间
# * temp_2：前天的最高温度值
# * temp_1：昨天的最高温度值
# * average：在历史中，每年这一天的平均最高温度值
# * actual：这就是我们的标签值了，当天的真实最高温度
# * friend：这一列可能是凑热闹的，你的朋友猜测的可能值，咱们不管它就好了

# %%
print('数据维度:', features.shape)
# Out:
# 数据维度: (348, 9)

# %%
# 处理时间数据
import datetime

# 分别得到年，月，日
years = features['year']
months = features['month']
days = features['day']

# datetime格式
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]

# %%
dates[:5]
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0),
#  datetime.datetime(2016, 1, 2, 0, 0),
#  datetime.datetime(2016, 1, 3, 0, 0),
#  datetime.datetime(2016, 1, 4, 0, 0),
#  datetime.datetime(2016, 1, 5, 0, 0)]

# %%
# 准备画图
# 指定默认风格
plt.style.use('fivethirtyeight')

# 设置布局
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize = (10,10))
fig.autofmt_xdate(rotation = 45)

# 标签值
ax1.plot(dates, features['actual'])
ax1.set_xlabel(''); ax1.set_ylabel('Temperature'); ax1.set_title('Max Temp')

# 昨天
ax2.plot(dates, features['temp_1'])
ax2.set_xlabel(''); ax2.set_ylabel('Temperature'); ax2.set_title('Previous Max Temp')

# 前天
ax3.plot(dates, features['temp_2'])
ax3.set_xlabel('Date'); ax3.set_ylabel('Temperature'); ax3.set_title('Two Days Prior Max Temp')

# 我的逗逼朋友
ax4.plot(dates, features['friend'])
ax4.set_xlabel('Date'); ax4.set_ylabel('Temperature'); ax4.set_title('Friend Estimate')

plt.tight_layout(pad=2)

# %%
# 独热编码
features = pd.get_dummies(features)
features.head(5)
# Out:
#    year  month  day  temp_2  temp_1  average  actual  friend  week_Fri  \
# 0  2016      1    1      45      45     45.6      45      29      True
# 1  2016      1    2      44      45     45.7      44      61     False
# 2  2016      1    3      45      44     45.8      41      56     False
# 3  2016      1    4      44      41     45.9      40      53     False
# 4  2016      1    5      41      40     46.0      44      41     False
#
#    week_Mon  week_Sat  week_Sun  week_Thurs  week_Tues  week_Wed
# 0     False     False     False       False      False     False
# 1     False      True     False       False      False     False
# 2     False     False      True       False      False     False
# 3      True     False     False       False      False     False
# 4     False     False     False       False       True     False

# %%
# 标签
labels = np.array(features['actual'])

# 在特征中去掉标签
features= features.drop('actual', axis = 1)

# 名字单独保存一下，以备后患
feature_list = list(features.columns)

# 转换成合适的格式
features = np.array(features)

# %%
features.shape
# Out:
# (348, 14)

# %%
from sklearn import preprocessing
input_features = preprocessing.StandardScaler().fit_transform(features)

# %%
input_features[0]
# Out:
# array([ 0.        , -1.5678393 , -1.65682171, -1.48452388, -1.49443549,
#        -1.3470703 , -1.98891668,  2.44131112, -0.40482045, -0.40961596,
#        -0.40482045, -0.40482045, -0.41913682, -0.40482045])

# %% [markdown]
# ### 构建网络模型

# %%
x = torch.tensor(input_features, dtype = float)

y = torch.tensor(labels, dtype = float)

# 权重参数初始化
weights = torch.randn((14, 128), dtype = float, requires_grad = True) 
biases = torch.randn(128, dtype = float, requires_grad = True) 
weights2 = torch.randn((128, 1), dtype = float, requires_grad = True) 
biases2 = torch.randn(1, dtype = float, requires_grad = True) 

learning_rate = 0.001 
losses = []

for i in range(1000):
    # 计算隐层
    hidden = x.mm(weights) + biases
    # 加入激活函数
    hidden = torch.relu(hidden)
    # 预测结果
    predictions = hidden.mm(weights2) + biases2
    # 通计算损失
    loss = torch.mean((predictions - y) ** 2) 
    losses.append(loss.data.numpy())
    
    # 打印损失值
    if i % 100 == 0:
        print('loss:', loss)
    #返向传播计算
    loss.backward()
    
    #更新参数
    weights.data.add_(- learning_rate * weights.grad.data)  
    biases.data.add_(- learning_rate * biases.grad.data)
    weights2.data.add_(- learning_rate * weights2.grad.data)
    biases2.data.add_(- learning_rate * biases2.grad.data)
    
    # 每次迭代都得记得清空
    weights.grad.data.zero_()
    biases.grad.data.zero_()
    weights2.grad.data.zero_()
    biases2.grad.data.zero_()
# Out:
# loss: tensor(2390.4275, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(150.8640, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(145.1847, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(143.1974, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(142.1602, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(141.5019, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(141.0569, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(140.7309, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(140.4805, dtype=torch.float64, grad_fn=<MeanBackward0>)
# loss: tensor(140.2847, dtype=torch.float64, grad_fn=<MeanBackward0>)

# %%
predictions.shape
# Out:
# torch.Size([348, 1])

# %% [markdown]
# ### 更简单的构建网络模型

# %%
# 特证数：14
input_size = input_features.shape[1]
# 隐层一神经元个数
hidden_size = 128
# 输出层神经元个数
output_size = 1
# 每次批量执行大小
batch_size = 16
# 定义神经网络
my_nn = torch.nn.Sequential(
    # 隐层一全连接(其中权重w、偏置b会自动生成)
    torch.nn.Linear(input_size, hidden_size),
    # 调用一次非线性函数
    torch.nn.Sigmoid(),
    # 输出层全连接
    torch.nn.Linear(hidden_size, output_size),
)
# 引入损失函数，计算损失值
cost = torch.nn.MSELoss(reduction='mean')
# 引入优化器，lr为学习率，相当于每次进步多少，这个建议小一点
optimizer = torch.optim.Adam(my_nn.parameters(), lr = 0.001)

# %%
# 训练网络
losses = []
# 循环次数可自定义配置，循环次数越多，训练的越好
for i in range(1000):
    batch_loss = []
    # MINI-Batch方法来进行训练
    for start in range(0, len(input_features), batch_size):
        # 按照批次计算，需要计算样本起始、结束位置
        end = start + batch_size if start + batch_size < len(input_features) else len(input_features)
        # xx、yy是批量的样本数据，不是全部样本数据
        xx = torch.tensor(input_features[start:end], dtype = torch.float, requires_grad = True)
        yy = torch.tensor(labels[start:end], dtype = torch.float, requires_grad = True)
        # 调用定义好的神经网络模型，prediction为预测出来的值
        prediction = my_nn(xx)
        # 调用定义好的损失函数，计算损失值（输入：预测值，真实值）
        loss = cost(prediction, yy)
        # 梯度清零，这个是必须加的，否则每次梯度会进行累加
        optimizer.zero_grad()
        # 反向传播
        loss.backward(retain_graph=True)
        # 参数更新（权重w及偏置b）随机生成，自动更新
        optimizer.step()
        # 存储计算损失，后续可做一些损失图表等
        batch_loss.append(loss.data.numpy())
    
    # 每100次打印损失，观察损失变化
    if i % 100==0:
        losses.append(np.mean(batch_loss))
        print(i, np.mean(batch_loss))
# Out:
# 0 3890.4338
# 100 37.926834
# 200 35.65255
# 300 35.27858
# 400 35.10459
# 500 34.966125
# 600 34.84329
# 700 34.72237
# 800 34.598373
# 900 34.470562

# %% [markdown]
# 预测训练结果

# %%
# 以上的步骤都是在训练模型，这块才是最终计算输入这批数据的预测值
# 将输入数据转换为tensor（张量）格式
x = torch.tensor(input_features, dtype = torch.float)
# 调用训练好的模型，计算这批数据，将输入每个样本的预测数据都存储到这个predict中
predict = my_nn(x).data.numpy()

# %%
# 创建真实值图表
# 转换日期格式
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]

# 创建一个表格来存日期和其对应的标签数值
true_data = pd.DataFrame(data = {'date': dates, 'actual': labels})

# 创建预测值图表
# 同理，再创建一个来存日期和其对应的模型预测值
months = features[:, feature_list.index('month')]
days = features[:, feature_list.index('day')]
years = features[:, feature_list.index('year')]

test_dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
test_dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in test_dates]

# 创建一个表格来存日期和其对应的预测值
predictions_data = pd.DataFrame(data = {'date': test_dates, 'prediction': predict.reshape(-1)})

# %%
# 绘制图表
# 真实值 b- : 蓝色线条
plt.plot(true_data['date'], true_data['actual'], 'b-', label = 'actual')

# 预测值 ro : 红色点
plt.plot(predictions_data['date'], predictions_data['prediction'], 'ro', label = 'prediction')
# x轴倾斜60度
plt.xticks(rotation=60)
plt.legend()
# 图名
plt.xlabel('Date'); plt.ylabel('Maximum Temperature (F)'); plt.title('Actual and Predicted Values');
